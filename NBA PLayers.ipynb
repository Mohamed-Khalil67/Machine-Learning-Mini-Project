# %% [markdown]
# # NBA Optimisation de Coorélation par Regression Linéaire

# %% [markdown]
# ### Problématique : Nombre de Points gagnés pour chaque joueur dés 1950

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
sns.set()

# %%
#charger les données 
#player_data.csv
player_data=pd.read_csv("player_data.csv")
#Players.csv
players=pd.read_csv("Players.csv")
#Seasons_Stats.csv
seasons_stats=pd.read_csv("Seasons_Stats.csv")
#vérifier si tous les individus ont bien un prix

# %%
player_data.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
players.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
seasons_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
players.drop(['Unnamed: 0'],axis='columns',inplace=True)
seasons_stats.drop(['Unnamed: 0'],axis='columns',inplace=True)

# %%
players.head()
# Out:
#             Player  height  weight                          collage    born  \
# 0  Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1     Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2    Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3       Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4      Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#     birth_city birth_state
# 0          NaN         NaN
# 1     Yorktown     Indiana
# 2          NaN         NaN
# 3          NaN         NaN
# 4  Hardinsburg    Kentucky

# %%
seasons_stats.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...  \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Partie1 : Analyse graphique des données (Dataviz)
# #### Diagrammes de répartition des données (type gaussienne sur les données) SeaBorne

# %%
# Les POS ont des NAN

# %%
seasons_stats.dtypes
# Out:
# Year      float64
# Player     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
# GS        float64
# MP        float64
# PER       float64
# TS%       float64
# 3PAr      float64
# FTr       float64
# ORB%      float64
# DRB%      float64
# TRB%      float64
# AST%      float64
# STL%      float64
# BLK%      float64
# TOV%      float64
# USG%      float64
# blanl     float64
# OWS       float64
# DWS       float64
# WS        float64
# WS/48     float64
# blank2    float64
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %%
players.dtypes
# Out:
# Player          object
# height         float64
# weight         float64
# collage         object
# born           float64
# birth_city      object
# birth_state     object
# dtype: object

# %%
player_data.dtypes
# Out:
# name           object
# year_start      int64
# year_end        int64
# position       object
# height         object
# weight        float64
# birth_date     object
# college        object
# dtype: object

# %%
players
# Out:
#                  Player  height  weight                          collage  \
# 0       Curly Armstrong   180.0    77.0               Indiana University
# 1          Cliff Barker   188.0    83.0           University of Kentucky
# 2         Leo Barnhorst   193.0    86.0         University of Notre Dame
# 3            Ed Bartels   196.0    88.0  North Carolina State University
# 4           Ralph Beard   178.0    79.0           University of Kentucky
# ...                 ...     ...     ...                              ...
# 3917      Troy Williams   198.0    97.0  South Carolina State University
# 3918       Kyle Wiltjer   208.0   108.0               Gonzaga University
# 3919  Stephen Zimmerman   213.0   108.0  University of Nevada, Las Vegas
# 3920        Paul Zipser   203.0    97.0                              NaN
# 3921        Ivica Zubac   216.0   120.0                              NaN
#
#         born      birth_city             birth_state
# 0     1918.0             NaN                     NaN
# 1     1921.0        Yorktown                 Indiana
# 2     1924.0             NaN                     NaN
# 3     1925.0             NaN                     NaN
# 4     1927.0     Hardinsburg                Kentucky
# ...      ...             ...                     ...
# 3917  1969.0        Columbia          South Carolina
# 3918  1992.0        Portland                  Oregon
# 3919  1996.0  Hendersonville               Tennessee
# 3920  1994.0      Heidelberg                 Germany
# 3921  1997.0          Mostar  Bosnia and Herzegovina
#
# [3922 rows x 7 columns]

# %%
Leo = (players['Player'] =='Leo Barnhorst')
Curly = (players['Player'] =='Curly Armstrong')
Cliff = (players['Player'] =='Cliff Barker')
Ed = (players['Player'] =='Ed Bartels')

# %%
sns.boxplot(x='Year', y='G', data=seasons_stats)
# Out:
# <div id='b3f8635b-e009-4aad-9c45-bcd04b8c7fae'></div>
# <AxesSubplot:xlabel='Year', ylabel='G'>

# %%
# Y = PTS
# X = 'G', 'height'

# %%
duplicas=seasons_stats.duplicated(keep=False,subset='Player')
seasons_stats[duplicas]
# Out:
#          Year           Player  Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0  Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0     Cliff Barker   SG  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0    Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0       Ed Bartels    F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0       Ed Bartels    F  24.0  DNN  13.0   NaN     NaN   NaN
# ...       ...              ...  ...   ...  ...   ...   ...     ...   ...
# 24683  2017.0        Joe Young   PG  24.0  IND  33.0   0.0   135.0  11.4
# 24684  2017.0       Nick Young   SG  31.0  LAL  60.0  60.0  1556.0  14.1
# 24685  2017.0   Thaddeus Young   PF  28.0  IND  74.0  74.0  2237.0  14.9
# 24686  2017.0      Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0     Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0  13.0
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST    STL   BLK   TOV  \
# 0      0.368  ...  0.705    NaN    NaN    NaN  176.0    NaN   NaN   NaN
# 1      0.435  ...  0.708    NaN    NaN    NaN  109.0    NaN   NaN   NaN
# 2      0.394  ...  0.698    NaN    NaN    NaN  140.0    NaN   NaN   NaN
# 3      0.312  ...  0.559    NaN    NaN    NaN   20.0    NaN   NaN   NaN
# 4      0.308  ...  0.548    NaN    NaN    NaN   20.0    NaN   NaN   NaN
# ...      ...  ...    ...    ...    ...    ...    ...    ...   ...   ...
# 24683  0.433  ...  0.733    1.0   16.0   17.0   15.0    4.0   0.0   5.0
# 24684  0.588  ...  0.856   25.0  112.0  137.0   58.0   37.0  14.0  36.0
# 24685  0.562  ...  0.523  131.0  318.0  449.0  122.0  114.0  30.0  96.0
# 24686  0.604  ...  0.679  135.0  270.0  405.0   99.0   62.0  58.0  65.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0   42.0    7.0  21.0  20.0
#
#           PF    PTS
# 0      217.0  458.0
# 1       99.0  279.0
# 2      192.0  438.0
# 3       29.0   63.0
# 4       27.0   59.0
# ...      ...    ...
# 24683    5.0   68.0
# 24684  137.0  791.0
# 24685  135.0  814.0
# 24686  189.0  639.0
# 24687   61.0  178.0
#
# [23747 rows x 52 columns]

# %%
doublons=seasons_stats[duplicas]
doublons
# Out:
#          Year           Player  Pos   Age   Tm     G    GS      MP   PER  \
# 0      1950.0  Curly Armstrong  G-F  31.0  FTW  63.0   NaN     NaN   NaN
# 1      1950.0     Cliff Barker   SG  29.0  INO  49.0   NaN     NaN   NaN
# 2      1950.0    Leo Barnhorst   SF  25.0  CHS  67.0   NaN     NaN   NaN
# 3      1950.0       Ed Bartels    F  24.0  TOT  15.0   NaN     NaN   NaN
# 4      1950.0       Ed Bartels    F  24.0  DNN  13.0   NaN     NaN   NaN
# ...       ...              ...  ...   ...  ...   ...   ...     ...   ...
# 24683  2017.0        Joe Young   PG  24.0  IND  33.0   0.0   135.0  11.4
# 24684  2017.0       Nick Young   SG  31.0  LAL  60.0  60.0  1556.0  14.1
# 24685  2017.0   Thaddeus Young   PF  28.0  IND  74.0  74.0  2237.0  14.9
# 24686  2017.0      Cody Zeller   PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0     Tyler Zeller    C  27.0  BOS  51.0   5.0   525.0  13.0
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST    STL   BLK   TOV  \
# 0      0.368  ...  0.705    NaN    NaN    NaN  176.0    NaN   NaN   NaN
# 1      0.435  ...  0.708    NaN    NaN    NaN  109.0    NaN   NaN   NaN
# 2      0.394  ...  0.698    NaN    NaN    NaN  140.0    NaN   NaN   NaN
# 3      0.312  ...  0.559    NaN    NaN    NaN   20.0    NaN   NaN   NaN
# 4      0.308  ...  0.548    NaN    NaN    NaN   20.0    NaN   NaN   NaN
# ...      ...  ...    ...    ...    ...    ...    ...    ...   ...   ...
# 24683  0.433  ...  0.733    1.0   16.0   17.0   15.0    4.0   0.0   5.0
# 24684  0.588  ...  0.856   25.0  112.0  137.0   58.0   37.0  14.0  36.0
# 24685  0.562  ...  0.523  131.0  318.0  449.0  122.0  114.0  30.0  96.0
# 24686  0.604  ...  0.679  135.0  270.0  405.0   99.0   62.0  58.0  65.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0   42.0    7.0  21.0  20.0
#
#           PF    PTS
# 0      217.0  458.0
# 1       99.0  279.0
# 2      192.0  438.0
# 3       29.0   63.0
# 4       27.0   59.0
# ...      ...    ...
# 24683    5.0   68.0
# 24684  137.0  791.0
# 24685  135.0  814.0
# 24686  189.0  639.0
# 24687   61.0  178.0
#
# [23747 rows x 52 columns]

# %%
seasons_stats2=doublons.groupby(['Player']).agg({'G':[sum],'PTS':[sum]})
seasons_stats2
# Out:
#                          G      PTS
#                        sum      sum
# Player
# A.C. Green          1361.0  12928.0
# A.J. English         151.0   1502.0
# A.J. Guyton           80.0    442.0
# A.J. Price           287.0   1656.0
# Aaron Brooks         797.0   7839.0
# ...                    ...      ...
# Zelmo Beaty*         570.0   9107.0
# Zendon Hamilton      146.0    611.0
# Zoran Dragic          32.0     56.0
# Zoran Planinic       148.0    561.0
# Zydrunas Ilgauskas   843.0  10976.0
#
# [2977 rows x 2 columns]

# %%
seasons_stats2=seasons_stats2.reset_index()
seasons_stats2
# Out:
#                   Player       G      PTS
#                              sum      sum
# 0             A.C. Green  1361.0  12928.0
# 1           A.J. English   151.0   1502.0
# 2            A.J. Guyton    80.0    442.0
# 3             A.J. Price   287.0   1656.0
# 4           Aaron Brooks   797.0   7839.0
# ...                  ...     ...      ...
# 2972        Zelmo Beaty*   570.0   9107.0
# 2973     Zendon Hamilton   146.0    611.0
# 2974        Zoran Dragic    32.0     56.0
# 2975      Zoran Planinic   148.0    561.0
# 2976  Zydrunas Ilgauskas   843.0  10976.0
#
# [2977 rows x 3 columns]

# %%
print(seasons_stats2)
# Out:
#                   Player       G      PTS
#                              sum      sum
# 0             A.C. Green  1361.0  12928.0
# 1           A.J. English   151.0   1502.0
# 2            A.J. Guyton    80.0    442.0
# 3             A.J. Price   287.0   1656.0
# 4           Aaron Brooks   797.0   7839.0
# ...                  ...     ...      ...
# 2972        Zelmo Beaty*   570.0   9107.0
# 2973     Zendon Hamilton   146.0    611.0
# 2974        Zoran Dragic    32.0     56.0
# 2975      Zoran Planinic   148.0    561.0
# 2976  Zydrunas Ilgauskas   843.0  10976.0
#
# [2977 rows x 3 columns]

# %%
seasons_stats2.columns=seasons_stats2.columns.droplevel(-1)
seasons_stats2
# Out:
#                   Player       G      PTS
# 0             A.C. Green  1361.0  12928.0
# 1           A.J. English   151.0   1502.0
# 2            A.J. Guyton    80.0    442.0
# 3             A.J. Price   287.0   1656.0
# 4           Aaron Brooks   797.0   7839.0
# ...                  ...     ...      ...
# 2972        Zelmo Beaty*   570.0   9107.0
# 2973     Zendon Hamilton   146.0    611.0
# 2974        Zoran Dragic    32.0     56.0
# 2975      Zoran Planinic   148.0    561.0
# 2976  Zydrunas Ilgauskas   843.0  10976.0
#
# [2977 rows x 3 columns]

# %%
seasons_stats2.head()
# Out:
#          Player       G      PTS
# 0    A.C. Green  1361.0  12928.0
# 1  A.J. English   151.0   1502.0
# 2   A.J. Guyton    80.0    442.0
# 3    A.J. Price   287.0   1656.0
# 4  Aaron Brooks   797.0   7839.0

# %%
inner_merged_total=pd.merge(seasons_stats2,seasons_stats,on=["Player"])
inner_merged_total
# Out:
#                    Player     G_x    PTS_x    Year Pos   Age   Tm   G_y    GS  \
# 0              A.C. Green  1361.0  12928.0  1986.0  PF  22.0  LAL  82.0   1.0
# 1              A.C. Green  1361.0  12928.0  1987.0  PF  23.0  LAL  79.0  72.0
# 2              A.C. Green  1361.0  12928.0  1988.0  PF  24.0  LAL  82.0  64.0
# 3              A.C. Green  1361.0  12928.0  1989.0  PF  25.0  LAL  82.0  82.0
# 4              A.C. Green  1361.0  12928.0  1990.0  PF  26.0  LAL  82.0  82.0
# ...                   ...     ...      ...     ...  ..   ...  ...   ...   ...
# 23675  Zydrunas Ilgauskas   843.0  10976.0  2007.0   C  31.0  CLE  78.0  78.0
# 23676  Zydrunas Ilgauskas   843.0  10976.0  2008.0   C  32.0  CLE  73.0  73.0
# 23677  Zydrunas Ilgauskas   843.0  10976.0  2009.0   C  33.0  CLE  65.0  65.0
# 23678  Zydrunas Ilgauskas   843.0  10976.0  2010.0   C  34.0  CLE  64.0   6.0
# 23679  Zydrunas Ilgauskas   843.0  10976.0  2011.0   C  35.0  MIA  72.0  51.0
#
#            MP  ...    FT%    ORB    DRB    TRB    AST   STL    BLK    TOV  \
# 0      1542.0  ...  0.611  160.0  221.0  381.0   54.0  49.0   49.0   99.0
# 1      2240.0  ...  0.780  210.0  405.0  615.0   84.0  70.0   80.0  102.0
# 2      2636.0  ...  0.773  245.0  465.0  710.0   93.0  87.0   45.0  120.0
# 3      2510.0  ...  0.786  258.0  481.0  739.0  103.0  94.0   55.0  119.0
# 4      2709.0  ...  0.751  262.0  450.0  712.0   90.0  66.0   50.0  116.0
# ...       ...  ...    ...    ...    ...    ...    ...   ...    ...    ...
# 23675  2130.0  ...  0.807  242.0  357.0  599.0  123.0  48.0   98.0  141.0
# 23676  2222.0  ...  0.802  263.0  419.0  682.0  104.0  34.0  120.0  135.0
# 23677  1765.0  ...  0.799  157.0  333.0  490.0   64.0  28.0   84.0   90.0
# 23678  1339.0  ...  0.743  114.0  231.0  345.0   48.0  14.0   50.0   63.0
# 23679  1145.0  ...  0.783  108.0  179.0  287.0   26.0  23.0   58.0   52.0
#
#           PF   PTS_y
# 0      229.0   521.0
# 1      171.0   852.0
# 2      204.0   937.0
# 3      172.0  1088.0
# 4      207.0  1061.0
# ...      ...     ...
# 23675  257.0   925.0
# 23676  247.0  1029.0
# 23677  183.0   838.0
# 23678  183.0   474.0
# 23679  185.0   360.0
#
# [23680 rows x 54 columns]

# %%
inner_merged_total.fillna(0,inplace=True)
inner_merged_total.isna().sum()
# Out:
# Player    0
# G_x       0
# PTS_x     0
# Year      0
# Pos       0
# Age       0
# Tm        0
# G_y       0
# GS        0
# MP        0
# PER       0
# TS%       0
# 3PAr      0
# FTr       0
# ORB%      0
# DRB%      0
# TRB%      0
# AST%      0
# STL%      0
# BLK%      0
# TOV%      0
# USG%      0
# blanl     0
# OWS       0
# DWS       0
# WS        0
# WS/48     0
# blank2    0
# OBPM      0
# DBPM      0
# BPM       0
# VORP      0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS_y     0
# dtype: int64

# %%
data_merge=inner_merged_total
X=data_merge[['G_x','MP','ORB','DRB']]
y=data_merge['PTS_x']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((16576, 4), (16576,))

# %%
X_test.shape, y_test.shape
# Out:
# ((7104, 4), (7104,))

# %%
regr= LinearRegression()
model=regr.fit(X_train,y_train)

# %%
model.coef_ , model.intercept_
# Out:
# (array([ 12.61651763,   1.47223082, -15.06961733,   4.8881405 ]),
#  -2674.3211008300186)

# %%
regr.predict(X_test)
# Out:
# array([ 7862.76008835, -2289.44528681, 12837.27778102, ...,
#         9181.36461533,  6517.13443489, 10230.80850733])

# %%
regr.score(X_test,y_test)
# Out:
# 0.7378534668258624
